# %% [markdown]
# # Grupo 1 - Plantas - Utilizamos una RNA MLP. Usando Keras para procesar las imágenes e identificar si es o no una planta

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho = 32 #@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
rna_cant_neuronas_capas_ocultas = '1500, D, 1500' #@param {type:"string"}
rna_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento = 200 #@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# cantidad de neuronas ocultas 
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )  
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )  
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print ("Tamaño Imagen: ", IMAGE_SHAPE)
print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Tamaño Imagen:  (32, 32, 3)
# Configuración de RNA MLP Backpropagation definida:
# [ 3072 ['1500', 'DropOut', '1500'] Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demoML/imagenes/PLANTAS' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  74
# - Imágenes cargadas:  74
# - Ejemplo  planta   (32, 32, 3) :
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FED29073810>
# > Para Prueba:
# - Clases cargadas:  18
# - Imágenes cargadas:  18
# - Ejemplo  planta   (32, 32, 3) :
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FED29180AD0>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (74, 3072)
#  - y_trainEnc (cant):  74
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (18, 3072)
#  - y_testEnc (cant):  18
#
#
# > Para Ambos:
#  - dictMapeo:  {'planta': 0, 'no_planta': 1}
#  - clases_map:  ['planta', 'no_planta']
#
#  - Imagen reconstruida de  planta ( 0  /  [1. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
#@title Establecer modelo

opt_tipo = "Gradiente Decreciente" #@param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.020 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for val_hid in hidden_layers:  

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  5  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 3072)]            0
#
#  hidd_1 (Dense)              (None, 1500)              4609500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  hidd_2 (Dense)              (None, 1500)              2251500
#
#  output (Dense)              (None, 2)                 3002
#
# =================================================================
# Total params: 6,864,002
# Trainable params: 6,864,002
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False #@param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  74 ejemplos de entrenamiento:
#             se usan  66 ejemplos para entrenar
#             y  8 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/200
# 3/3 [==============================] - 3s 94ms/step - loss: 0.8553 - accuracy: 0.5606 - val_loss: 29.1747 - val_accuracy: 0.5000
# Epoch 2/200
# 3/3 [==============================] - 0s 13ms/step - loss: 18.2228 - accuracy: 0.4394 - val_loss: 4.5052 - val_accuracy: 0.5000
# Epoch 3/200
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4113 - accuracy: 0.6364 - val_loss: 4.9397 - val_accuracy: 0.5000
# Epoch 4/200
# 3/3 [==============================] - 0s 13ms/step - loss: 2.3519 - accuracy: 0.6364 - val_loss: 0.7570 - val_accuracy: 0.5000
# Epoch 5/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5865 - accuracy: 0.6970 - val_loss: 0.9237 - val_accuracy: 0.2500
# Epoch 6/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9318 - accuracy: 0.5000 - val_loss: 2.8597 - val_accuracy: 0.5000
# Epoch 7/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5191 - accuracy: 0.6061 - val_loss: 0.9220 - val_accuracy: 0.5000
# Epoch 8/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6630 - accuracy: 0.7273 - val_loss: 1.9606 - val_accuracy: 0.5000
# Epoch 9/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8558 - accuracy: 0.7121 - val_loss: 1.1451 - val_accuracy: 0.3750
# Epoch 10/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7500 - accuracy: 0.6212 - val_loss: 1.8003 - val_accuracy: 0.5000
# Epoch 11/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8637 - accuracy: 0.6667 - val_loss: 0.8789 - val_accuracy: 0.6250
# Epoch 12/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4664 - accuracy: 0.7727 - val_loss: 0.8067 - val_accuracy: 0.6250
# Epoch 13/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4909 - accuracy: 0.8030 - val_loss: 0.8236 - val_accuracy: 0.3750
# Epoch 14/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4614 - accuracy: 0.8030 - val_loss: 0.7342 - val_accuracy: 0.6250
# Epoch 15/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4362 - accuracy: 0.8485 - val_loss: 0.7961 - val_accuracy: 0.5000
# Epoch 16/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3973 - accuracy: 0.8333 - val_loss: 0.9218 - val_accuracy: 0.5000
# Epoch 17/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4084 - accuracy: 0.8030 - val_loss: 0.7174 - val_accuracy: 0.5000
# Epoch 18/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3555 - accuracy: 0.8636 - val_loss: 0.6733 - val_accuracy: 0.6250
# Epoch 19/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3431 - accuracy: 0.8182 - val_loss: 2.9598 - val_accuracy: 0.5000
# Epoch 20/200
# 3/3 [==============================] - 0s 15ms/step - loss: 1.6175 - accuracy: 0.4697 - val_loss: 0.7124 - val_accuracy: 0.5000
# Epoch 21/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3994 - accuracy: 0.8485 - val_loss: 1.5972 - val_accuracy: 0.3750
# Epoch 22/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9380 - accuracy: 0.5909 - val_loss: 1.2178 - val_accuracy: 0.5000
# Epoch 23/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6000 - accuracy: 0.7121 - val_loss: 0.7735 - val_accuracy: 0.6250
# Epoch 24/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5102 - accuracy: 0.7121 - val_loss: 1.0767 - val_accuracy: 0.2500
# Epoch 25/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7027 - accuracy: 0.6818 - val_loss: 0.7260 - val_accuracy: 0.5000
# Epoch 26/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4571 - accuracy: 0.8182 - val_loss: 0.7778 - val_accuracy: 0.6250
# Epoch 27/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3586 - accuracy: 0.8788 - val_loss: 1.1600 - val_accuracy: 0.5000
# Epoch 28/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5324 - accuracy: 0.7273 - val_loss: 1.4652 - val_accuracy: 0.5000
# Epoch 29/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8677 - accuracy: 0.5606 - val_loss: 2.1302 - val_accuracy: 0.5000
# Epoch 30/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0694 - accuracy: 0.5909 - val_loss: 0.6661 - val_accuracy: 0.6250
# Epoch 31/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4834 - accuracy: 0.7727 - val_loss: 1.3215 - val_accuracy: 0.5000
# Epoch 32/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6855 - accuracy: 0.6515 - val_loss: 1.1045 - val_accuracy: 0.5000
# Epoch 33/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6363 - accuracy: 0.6818 - val_loss: 0.7054 - val_accuracy: 0.6250
# Epoch 34/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3938 - accuracy: 0.8939 - val_loss: 0.8424 - val_accuracy: 0.5000
# Epoch 35/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4981 - accuracy: 0.7727 - val_loss: 1.1422 - val_accuracy: 0.5000
# Epoch 36/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4456 - accuracy: 0.8030 - val_loss: 0.8868 - val_accuracy: 0.2500
# Epoch 37/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5152 - accuracy: 0.7879 - val_loss: 3.9428 - val_accuracy: 0.5000
# Epoch 38/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4131 - accuracy: 0.7121 - val_loss: 1.7426 - val_accuracy: 0.5000
# Epoch 39/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8442 - accuracy: 0.6061 - val_loss: 1.0538 - val_accuracy: 0.5000
# Epoch 40/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3478 - accuracy: 0.8485 - val_loss: 0.7242 - val_accuracy: 0.5000
# Epoch 41/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3609 - accuracy: 0.8636 - val_loss: 0.7233 - val_accuracy: 0.6250
# Epoch 42/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5487 - accuracy: 0.6818 - val_loss: 0.8108 - val_accuracy: 0.3750
# Epoch 43/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4433 - accuracy: 0.8030 - val_loss: 0.8429 - val_accuracy: 0.6250
# Epoch 44/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3518 - accuracy: 0.8636 - val_loss: 0.8459 - val_accuracy: 0.5000
# Epoch 45/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4449 - accuracy: 0.8182 - val_loss: 0.6131 - val_accuracy: 0.7500
# Epoch 46/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4244 - accuracy: 0.7879 - val_loss: 0.6694 - val_accuracy: 0.6250
# Epoch 47/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3560 - accuracy: 0.8636 - val_loss: 0.5508 - val_accuracy: 0.6250
# Epoch 48/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3264 - accuracy: 0.8333 - val_loss: 2.1601 - val_accuracy: 0.5000
# Epoch 49/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5792 - accuracy: 0.8030 - val_loss: 0.9608 - val_accuracy: 0.5000
# Epoch 50/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3370 - accuracy: 0.8333 - val_loss: 0.8218 - val_accuracy: 0.5000
# Epoch 51/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2592 - accuracy: 0.9091 - val_loss: 0.6819 - val_accuracy: 0.6250
# Epoch 52/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4283 - accuracy: 0.7576 - val_loss: 0.9328 - val_accuracy: 0.5000
# Epoch 53/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6140 - accuracy: 0.7273 - val_loss: 1.0070 - val_accuracy: 0.5000
# Epoch 54/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2991 - accuracy: 0.8788 - val_loss: 2.2894 - val_accuracy: 0.5000
# Epoch 55/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.7809 - accuracy: 0.5455 - val_loss: 1.3058 - val_accuracy: 0.3750
# Epoch 56/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0704 - accuracy: 0.6212 - val_loss: 0.7764 - val_accuracy: 0.5000
# Epoch 57/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3232 - accuracy: 0.8788 - val_loss: 1.2238 - val_accuracy: 0.5000
# Epoch 58/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4810 - accuracy: 0.7727 - val_loss: 0.6305 - val_accuracy: 0.6250
# Epoch 59/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2948 - accuracy: 0.8182 - val_loss: 0.6144 - val_accuracy: 0.6250
# Epoch 60/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2828 - accuracy: 0.8788 - val_loss: 0.8910 - val_accuracy: 0.5000
# Epoch 61/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4966 - accuracy: 0.7576 - val_loss: 2.0220 - val_accuracy: 0.3750
# Epoch 62/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.6168 - accuracy: 0.5152 - val_loss: 0.6174 - val_accuracy: 0.6250
# Epoch 63/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3360 - accuracy: 0.8485 - val_loss: 0.7534 - val_accuracy: 0.5000
# Epoch 64/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2660 - accuracy: 0.9091 - val_loss: 0.5939 - val_accuracy: 0.6250
# Epoch 65/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2659 - accuracy: 0.9242 - val_loss: 0.6809 - val_accuracy: 0.7500
# Epoch 66/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2337 - accuracy: 0.9091 - val_loss: 0.7864 - val_accuracy: 0.6250
# Epoch 67/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2765 - accuracy: 0.8788 - val_loss: 0.6295 - val_accuracy: 0.6250
# Epoch 68/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2137 - accuracy: 0.9091 - val_loss: 1.1471 - val_accuracy: 0.5000
# Epoch 69/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4534 - accuracy: 0.7424 - val_loss: 1.2281 - val_accuracy: 0.5000
# Epoch 70/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5089 - accuracy: 0.7121 - val_loss: 1.3008 - val_accuracy: 0.5000
# Epoch 71/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3755 - accuracy: 0.8333 - val_loss: 0.7190 - val_accuracy: 0.7500
# Epoch 72/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1842 - accuracy: 0.9242 - val_loss: 0.6730 - val_accuracy: 0.6250
# Epoch 73/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2187 - accuracy: 0.8788 - val_loss: 1.0193 - val_accuracy: 0.5000
# Epoch 74/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1741 - accuracy: 0.9394 - val_loss: 0.7098 - val_accuracy: 0.6250
# Epoch 75/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2581 - accuracy: 0.9091 - val_loss: 0.7165 - val_accuracy: 0.7500
# Epoch 76/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1829 - accuracy: 0.9091 - val_loss: 1.0398 - val_accuracy: 0.3750
# Epoch 77/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5946 - accuracy: 0.7273 - val_loss: 0.9878 - val_accuracy: 0.6250
# Epoch 78/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1798 - accuracy: 0.9242 - val_loss: 1.3496 - val_accuracy: 0.5000
# Epoch 79/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2175 - accuracy: 0.9242 - val_loss: 1.7464 - val_accuracy: 0.3750
# Epoch 80/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4015 - accuracy: 0.5455 - val_loss: 0.7218 - val_accuracy: 0.6250
# Epoch 81/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1903 - accuracy: 0.9394 - val_loss: 0.6654 - val_accuracy: 0.7500
# Epoch 82/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1741 - accuracy: 0.9394 - val_loss: 0.5968 - val_accuracy: 0.6250
# Epoch 83/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1699 - accuracy: 0.9394 - val_loss: 0.6056 - val_accuracy: 0.7500
# Epoch 84/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1582 - accuracy: 0.9545 - val_loss: 0.6928 - val_accuracy: 0.7500
# Epoch 85/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2581 - accuracy: 0.8939 - val_loss: 0.6231 - val_accuracy: 0.6250
# Epoch 86/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1820 - accuracy: 0.9394 - val_loss: 0.6579 - val_accuracy: 0.7500
# Epoch 87/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3247 - accuracy: 0.8333 - val_loss: 0.6418 - val_accuracy: 0.6250
# Epoch 88/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1291 - accuracy: 0.9848 - val_loss: 0.6550 - val_accuracy: 0.6250
# Epoch 89/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1529 - accuracy: 0.9394 - val_loss: 1.3828 - val_accuracy: 0.5000
# Epoch 90/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3145 - accuracy: 0.7879 - val_loss: 0.8084 - val_accuracy: 0.6250
# Epoch 91/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1442 - accuracy: 0.9697 - val_loss: 0.7641 - val_accuracy: 0.6250
# Epoch 92/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1190 - accuracy: 0.9848 - val_loss: 1.6222 - val_accuracy: 0.3750
# Epoch 93/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9181 - accuracy: 0.6818 - val_loss: 1.2879 - val_accuracy: 0.5000
# Epoch 94/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4087 - accuracy: 0.8030 - val_loss: 2.1033 - val_accuracy: 0.3750
# Epoch 95/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7098 - accuracy: 0.7576 - val_loss: 0.6894 - val_accuracy: 0.6250
# Epoch 96/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2462 - accuracy: 0.8939 - val_loss: 4.4336 - val_accuracy: 0.5000
# Epoch 97/200
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7054 - accuracy: 0.6212 - val_loss: 0.7387 - val_accuracy: 0.5000
# Epoch 98/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4572 - accuracy: 0.7273 - val_loss: 2.7760 - val_accuracy: 0.5000
# Epoch 99/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.3996 - accuracy: 0.6212 - val_loss: 0.9418 - val_accuracy: 0.5000
# Epoch 100/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2821 - accuracy: 0.9091 - val_loss: 0.5595 - val_accuracy: 0.6250
# Epoch 101/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2225 - accuracy: 0.9242 - val_loss: 1.1671 - val_accuracy: 0.3750
# Epoch 102/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5173 - accuracy: 0.7727 - val_loss: 0.7507 - val_accuracy: 0.6250
# Epoch 103/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1850 - accuracy: 0.9242 - val_loss: 0.8154 - val_accuracy: 0.6250
# Epoch 104/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1540 - accuracy: 0.9697 - val_loss: 0.5954 - val_accuracy: 0.6250
# Epoch 105/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1590 - accuracy: 0.9697 - val_loss: 0.6348 - val_accuracy: 0.6250
# Epoch 106/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1481 - accuracy: 0.9697 - val_loss: 2.8497 - val_accuracy: 0.3750
# Epoch 107/200
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0441 - accuracy: 0.6515 - val_loss: 0.6264 - val_accuracy: 0.6250
# Epoch 108/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1475 - accuracy: 0.9545 - val_loss: 0.7239 - val_accuracy: 0.6250
# Epoch 109/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1180 - accuracy: 0.9848 - val_loss: 2.2321 - val_accuracy: 0.5000
# Epoch 110/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6843 - accuracy: 0.7424 - val_loss: 0.6837 - val_accuracy: 0.7500
# Epoch 111/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1371 - accuracy: 0.9697 - val_loss: 0.6066 - val_accuracy: 0.6250
# Epoch 112/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1096 - accuracy: 0.9697 - val_loss: 0.6630 - val_accuracy: 0.7500
# Epoch 113/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1012 - accuracy: 0.9848 - val_loss: 0.5885 - val_accuracy: 0.7500
# Epoch 114/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1369 - accuracy: 0.9848 - val_loss: 1.0149 - val_accuracy: 0.5000
# Epoch 115/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2060 - accuracy: 0.9242 - val_loss: 1.0126 - val_accuracy: 0.5000
# Epoch 116/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1628 - accuracy: 0.9545 - val_loss: 0.7510 - val_accuracy: 0.7500
# Epoch 117/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0833 - accuracy: 0.9848 - val_loss: 0.7798 - val_accuracy: 0.6250
# Epoch 118/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.3083 - val_accuracy: 0.3750
# Epoch 119/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5108 - accuracy: 0.7879 - val_loss: 0.6560 - val_accuracy: 0.7500
# Epoch 120/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0767 - accuracy: 0.9848 - val_loss: 0.8665 - val_accuracy: 0.6250
# Epoch 121/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.6276 - val_accuracy: 0.8750
# Epoch 122/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0683 - accuracy: 0.9848 - val_loss: 0.6222 - val_accuracy: 0.8750
# Epoch 123/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0584 - accuracy: 0.9848 - val_loss: 0.6078 - val_accuracy: 0.8750
# Epoch 124/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0617 - accuracy: 0.9848 - val_loss: 0.6544 - val_accuracy: 0.8750
# Epoch 125/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 1.5993 - val_accuracy: 0.5000
# Epoch 126/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0270 - accuracy: 0.6061 - val_loss: 2.5509 - val_accuracy: 0.5000
# Epoch 127/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7201 - accuracy: 0.7727 - val_loss: 1.5407 - val_accuracy: 0.5000
# Epoch 128/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1593 - accuracy: 0.9242 - val_loss: 0.8011 - val_accuracy: 0.5000
# Epoch 129/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1126 - accuracy: 0.9545 - val_loss: 4.5233 - val_accuracy: 0.5000
# Epoch 130/200
# 3/3 [==============================] - 0s 13ms/step - loss: 1.8825 - accuracy: 0.7576 - val_loss: 0.6307 - val_accuracy: 0.7500
# Epoch 131/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1073 - accuracy: 0.9848 - val_loss: 0.7262 - val_accuracy: 0.7500
# Epoch 132/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1179 - accuracy: 0.9697 - val_loss: 0.7277 - val_accuracy: 0.7500
# Epoch 133/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1154 - accuracy: 0.9545 - val_loss: 0.7760 - val_accuracy: 0.7500
# Epoch 134/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0839 - accuracy: 1.0000 - val_loss: 0.6371 - val_accuracy: 0.7500
# Epoch 135/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 0.6610 - val_accuracy: 0.7500
# Epoch 136/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0739 - accuracy: 0.9848 - val_loss: 1.4630 - val_accuracy: 0.5000
# Epoch 137/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3436 - accuracy: 0.8030 - val_loss: 1.5704 - val_accuracy: 0.5000
# Epoch 138/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2849 - accuracy: 0.8636 - val_loss: 0.6640 - val_accuracy: 0.7500
# Epoch 139/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0581 - accuracy: 0.9848 - val_loss: 0.8280 - val_accuracy: 0.7500
# Epoch 140/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 1.1121 - val_accuracy: 0.5000
# Epoch 141/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3122 - accuracy: 0.8485 - val_loss: 1.3812 - val_accuracy: 0.5000
# Epoch 142/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3615 - accuracy: 0.8333 - val_loss: 2.1756 - val_accuracy: 0.3750
# Epoch 143/200
# 3/3 [==============================] - 0s 16ms/step - loss: 2.0650 - accuracy: 0.5606 - val_loss: 2.7870 - val_accuracy: 0.5000
# Epoch 144/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8263 - accuracy: 0.8182 - val_loss: 0.5764 - val_accuracy: 0.7500
# Epoch 145/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1037 - accuracy: 0.9848 - val_loss: 0.6366 - val_accuracy: 0.7500
# Epoch 146/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0923 - accuracy: 0.9848 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 147/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0871 - accuracy: 1.0000 - val_loss: 1.7019 - val_accuracy: 0.5000
# Epoch 148/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2374 - accuracy: 0.8485 - val_loss: 0.5898 - val_accuracy: 0.7500
# Epoch 149/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1170 - accuracy: 0.9242 - val_loss: 0.6111 - val_accuracy: 0.7500
# Epoch 150/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 0.6200 - val_accuracy: 0.7500
# Epoch 151/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0618 - accuracy: 1.0000 - val_loss: 1.7751 - val_accuracy: 0.5000
# Epoch 152/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1879 - accuracy: 0.8939 - val_loss: 0.7365 - val_accuracy: 0.6250
# Epoch 153/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2875 - accuracy: 0.8636 - val_loss: 6.0328 - val_accuracy: 0.5000
# Epoch 154/200
# 3/3 [==============================] - 0s 15ms/step - loss: 2.0949 - accuracy: 0.7424 - val_loss: 0.6091 - val_accuracy: 0.6250
# Epoch 155/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1162 - accuracy: 0.9697 - val_loss: 0.8007 - val_accuracy: 0.6250
# Epoch 156/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1204 - accuracy: 0.9697 - val_loss: 0.6498 - val_accuracy: 0.7500
# Epoch 157/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1070 - accuracy: 0.9848 - val_loss: 0.5819 - val_accuracy: 0.6250
# Epoch 158/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0962 - accuracy: 0.9848 - val_loss: 0.7269 - val_accuracy: 0.7500
# Epoch 159/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0816 - accuracy: 0.9848 - val_loss: 0.5898 - val_accuracy: 0.6250
# Epoch 160/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0948 - accuracy: 0.9545 - val_loss: 0.5934 - val_accuracy: 0.6250
# Epoch 161/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1005 - accuracy: 0.9848 - val_loss: 0.6586 - val_accuracy: 0.7500
# Epoch 162/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.9688 - val_accuracy: 0.6250
# Epoch 163/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0719 - accuracy: 0.9848 - val_loss: 0.6963 - val_accuracy: 0.7500
# Epoch 164/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.5823 - val_accuracy: 0.8750
# Epoch 165/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.5935 - val_accuracy: 0.8750
# Epoch 166/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.6276 - val_accuracy: 0.8750
# Epoch 167/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.6418 - val_accuracy: 0.8750
# Epoch 168/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.6182 - val_accuracy: 0.8750
# Epoch 169/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0571 - accuracy: 1.0000 - val_loss: 1.4829 - val_accuracy: 0.3750
# Epoch 170/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6113 - accuracy: 0.7879 - val_loss: 3.9472 - val_accuracy: 0.5000
# Epoch 171/200
# 3/3 [==============================] - 0s 14ms/step - loss: 3.6989 - accuracy: 0.3788 - val_loss: 0.9208 - val_accuracy: 0.5000
# Epoch 172/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2298 - accuracy: 0.9091 - val_loss: 0.5070 - val_accuracy: 0.7500
# Epoch 173/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1516 - accuracy: 0.9545 - val_loss: 0.5038 - val_accuracy: 0.7500
# Epoch 174/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.7500
# Epoch 175/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1139 - accuracy: 0.9697 - val_loss: 0.5406 - val_accuracy: 0.7500
# Epoch 176/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1188 - accuracy: 0.9394 - val_loss: 1.0176 - val_accuracy: 0.5000
# Epoch 177/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1730 - accuracy: 0.9394 - val_loss: 0.5777 - val_accuracy: 0.7500
# Epoch 178/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0956 - accuracy: 0.9545 - val_loss: 0.8970 - val_accuracy: 0.6250
# Epoch 179/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.8750
# Epoch 180/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.5715 - val_accuracy: 0.8750
# Epoch 181/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.7500
# Epoch 182/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1492 - accuracy: 0.9848 - val_loss: 0.5879 - val_accuracy: 0.8750
# Epoch 183/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.8897 - val_accuracy: 0.6250
# Epoch 184/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8750
# Epoch 185/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.6111 - val_accuracy: 0.8750
# Epoch 186/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.8441 - val_accuracy: 0.6250
# Epoch 187/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0418 - accuracy: 0.9848 - val_loss: 0.6376 - val_accuracy: 0.7500
# Epoch 188/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.6668 - val_accuracy: 0.7500
# Epoch 189/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.7141 - val_accuracy: 0.7500
# Epoch 190/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.7868 - val_accuracy: 0.7500
# Epoch 191/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.7281 - val_accuracy: 0.7500
# Epoch 192/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.6798 - val_accuracy: 0.7500
# Epoch 193/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.6841 - val_accuracy: 0.7500
# Epoch 194/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.7008 - val_accuracy: 0.7500
# Epoch 195/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.6401 - val_accuracy: 0.7500
# Epoch 196/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.6821 - val_accuracy: 0.8750
# Epoch 197/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.7678 - val_accuracy: 0.7500
# Epoch 198/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.7650 - val_accuracy: 0.7500
# Epoch 199/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0950 - accuracy: 0.9394 - val_loss: 0.8359 - val_accuracy: 0.7500
# Epoch 200/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.6250
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
mostrar_detalle_imagenes_entrenamiento = False #@param {type:"boolean"}

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map, mostrarImagenes=False):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if mostrarImagenes:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\n Matriz de Confusión ( real / modelo ): ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['m:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    if mostrarImagenes:
      print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map, mostrar_detalle_imagenes_entrenamiento)
# Out:
# *** Resultados con datos de Entrenamiento:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#    no_planta       1.00      0.92      0.96        37
#       planta       0.93      1.00      0.96        37
#
#     accuracy                           0.96        74
#    macro avg       0.96      0.96      0.96        74
# weighted avg       0.96      0.96      0.96        74
#
#
#  Matriz de Confusión ( real / modelo ):
#              m:planta  m:no_planta
# r:planta           37            0
# r:no_planta         3           34

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
mostrar_detalle_imagenes_prueba = False #@param {type:"boolean"}
 
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map, mostrar_detalle_imagenes_prueba)
# Out:
# 1/1 [==============================] - 0s 19ms/step - loss: 0.8604 - accuracy: 0.6111
#
# >Evaluación del Modelo:
#     - Error:  0.86042320728302
#     - Exactitud:  61.11111044883728
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#    no_planta       0.78      0.58      0.67        12
#       planta       0.44      0.67      0.53         6
#
#     accuracy                           0.61        18
#    macro avg       0.61      0.62      0.60        18
# weighted avg       0.67      0.61      0.62        18
#
#
#  Matriz de Confusión ( real / modelo ):
#              m:planta  m:no_planta
# r:planta            4            2
# r:no_planta         5            7
